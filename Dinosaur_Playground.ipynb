# %% [markdown]
# # Dinosaur EDA Playground
# Bienvenido al cuaderno de pruebas de la librería **Dinosaur**. Aquí podrás testear tu dataset paso a paso.

# %% [markdown]
# ### 1. Importar la librería

# %%
import dinosaur as dino
import pandas as pd

# %% [markdown]
# ### 2. Cargar el Dataset
# Usaremos el archivo `full_dataset_thesis - 1.csv`.

# %%
dataset_path = "full_dataset_thesis - 1.csv"
explorer = dino.Dinosaur(dataset_path)
explorer.df.head()
# Out:
#   Season                     Injury     Days  Games missed injury_from_parsed  \
# 0  20/21  Syndesmosis ligament tear  43 days             9          1/28/2021
# 1  20/21                Knee injury  37 days             6           3/7/2021
# 2  20/21               Corona virus  21 days             4          2/17/2021
# 3  20/21                     bruise   8 days             2          11/6/2020
# 4  20/21            Ligament injury  22 days             2          7/26/2020
#
#   injury_until_parsed           player_name  player_age player_position  \
# 0           3/11/2021       Alexander Nübel          24      Goalkeeper
# 1           4/12/2021  Ron-Thorben Hoffmann          22      Goalkeeper
# 2            3/9/2021       Benjamin Pavard          25     Centre-Back
# 3          11/13/2020       Benjamin Pavard          25     Centre-Back
# 4           8/16/2020       Benjamin Pavard          25     Centre-Back
#
#             club      league
# 0  Bayern Munich  Bundesliga
# ...

# %% [markdown]
# ### 3. Reporte de Calidad
# Revisamos nulos, duplicados y dimensiones.

# %%
explorer.report()
# Out:
# ------------------------------
# DINOSAUR DATA QUALITY REPORT
# ------------------------------
# Total Rows: 15603
# Total Columns: 11
# Duplicates: 0
#
# No missing values found! Great job.
# ------------------------------

# %% [markdown]
# ### 4. Visualización de Distribuciones
# Analiza cómo se distribuyen tus variables numéricas.

# %%
explorer.visualize(mode='distributions')

# %% [markdown]
# ### 5. Análisis de Correlación
# ¿Cómo se relacionan tus variables entre sí?

# %%
explorer.visualize(mode='correlation')

# %% [markdown]
# ### 6. Matriz de Valores Faltantes

# %%
explorer.visualize(mode='missing')
